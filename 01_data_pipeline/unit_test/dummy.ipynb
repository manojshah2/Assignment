# %%
from utils import *

# %%
build_dbs()
# Out:
# DB Already Exists
# d:\Learning\ML AI\MLOps Assignment\Assignment\01_data_pipeline\unit_test

# %%
load_data_into_db()

# %%
map_city_tier()

# %%
map_categorical_vars()
# Out:
# Storing mapped df to table categorical_variables_mapped
# d:\Learning\ML AI\MLOps Assignment\Assignment\01_data_pipeline\unit_test\utils.py:201: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['first_platform_c'] = "others" # replace the value of these levels to others
# d:\Learning\ML AI\MLOps Assignment\Assignment\01_data_pipeline\unit_test\utils.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
interactions_mapping()
