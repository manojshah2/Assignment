# %%
from utils import *
from data_validation_checks import *

# %%
build_dbs()
# Out:
# DB Already Exists
# d:\Learning\ML AI\MLOps Assignment\Assignment\01_data_pipeline\scripts

# %%
load_data_into_db()

# %%
map_city_tier()

# %%
map_categorical_vars()
# Out:
# d:\Learning\ML AI\MLOps Assignment\Assignment\01_data_pipeline\scripts\utils.py:201: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['first_platform_c'] = "others" # replace the value of these levels to others
# d:\Learning\ML AI\MLOps Assignment\Assignment\01_data_pipeline\scripts\utils.py:207: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['first_utm_medium_c'] = "others" # replace the value of these levels to others
# d:\Learning\ML AI\MLOps Assignment\Assignment\01_data_pipeline\scripts\utils.py:213: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['first_utm_source_c'] = "others" # replace the value of these levels to others
# Storing mapped df to table categorical_variables_mapped

# %%
interactions_mapping()

# %%
raw_data_schema_check()
# Out:
# Raw datas schema is in line with the schema present in schema.py

# %%
model_input_schema_check()
# Out:
# Models input schema is in line with the schema present in schema.py
